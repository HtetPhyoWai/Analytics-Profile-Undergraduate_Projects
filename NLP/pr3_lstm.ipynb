# %%
# !apt-get install --no-install-recommends openmpi-bin libopenmpi-dev libopencv-dev python3-opencv python-opencv && ln -sf /usr/lib/x86_64-linux-gnu/libmpi_cxx.so /usr/lib/x86_64-linux-gnu/libmpi_cxx.so.1 && ln -sf /usr/lib/x86_64-linux-gnu/openmpi/lib/libmpi.so /usr/lib/x86_64-linux-gnu/openmpi/lib/libmpi.so.12 && ln -sf /usr/lib/x86_64-linux-gnu/libmpi.so /usr/lib/x86_64-linux-gnu/libmpi.so.12 && pip install cntk

# %%
import math
import numpy as np
import os
from __future__ import print_function # Use a function definition from future version (say 3.x from 2.7 interpreter)

import cntk as C
import cntk.tests.test_utils
cntk.tests.test_utils.set_device_from_pytest_env() # (only needed for our build system)
C.cntk_py.set_fixed_random_seed(1) # fix a random seed for CNTK components
# Out:
# /usr/local/lib/python3.6/dist-packages/cntk/cntk_py_init.py:56: UserWarning: Unsupported Linux distribution (ubuntu-18.04). CNTK supports Ubuntu 16.04 and above, only.
#   warnings.warn('Unsupported Linux distribution (%s-%s). CNTK supports Ubuntu 16.04 and above, only.' % (__my_distro__, __my_distro_ver__))

# %%
from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-5e949a5e-6034-406e-af7b-ea1950d985db" name="files[]" multiple disabled />
#      <output id="result-5e949a5e-6034-406e-af7b-ea1950d985db">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.pair.tok.ctf.csv to train.pair.tok.ctf.csv
# Saving valid.pair.tok.ctf.csv to valid.pair.tok.ctf.csv
# Saving vocab_A.wl.csv to vocab_A.wl.csv
# Saving vocab_Q.wl.csv to vocab_Q.wl.csv
# {'train.pair.tok.ctf.csv': b'0\t|S0 1160:1\t|S1 956:1\r\n0\t|S0 569:1\t|S1 958:1\r\n0\t|S0 806:1\t|S1 55:1\r\n0\t|S0 357:1\t|S1 956:1\r\n0\t|S0 746:1\t|S1 787:1\r\n0\t|S0 455:1\t|S1 7:1\r\n0\t|S0 532:1\t\r\n1\t|S0 1154:1\t|S1 356:1\r\n1\t|S0 80:1\t|S1 7:1\r\n1\t|S0 61:1\t|S1 356:1\r\n1\t|S0 1052:1\t|S1 356:1\r\n1\t|S0 700:1\t|S1 687:1\r\n1\t|S0 357:1\t|S1 356:1\r\n1\t|S0 504:1\t\r\n1\t|S0 126:1\t\r\n1\t|S0 549:1\t\r\n2\t|S0 1157:1\t|S1 47:1\r\n2\t|S0 337:1\t|S1 375:1\r\n2\t|S0 357:1\t|S1 242:1\r\n2\t|S0 803:1\t|S1 876:1\r\n2\t\t|S1 889:1\r\n2\t\t|S1 920:1\r\n3\t|S0 1160:1\t|S1 93:1\r\n3\t|S0 569:1\t|S1 98:1\r\n3\t|S0 663:1\t|S1 97:1\r\n3\t|S0 1070:1\t|S1 93:1\r\n3\t|S0 357:1\t|S1 96:1\r\n3\t\t|S1 98:1\r\n4\t|S0 1160:1\t|S1 356:1\r\n4\t|S0 1140:1\t|S1 7:1\r\n4\t|S0 357:1\t|S1 356:1\r\n4\t|S0 549:1\t|S1 356:1\r\n4\t|S0 967:1\t|S1 687:1\r\n4\t|S0 1021:1\t|S1 171:1\r\n5\t|S0 1154:1\t|S1 685:1\r\n5\t|S0 1112:1\t|S1 691:1\r\n5\t|S0 321:1\t|S1 315:1\r\n5\t|S0 357:1\t|S1 315:1\r\n5\t|S0 467:1\t|S1 315:1\r\n5\t|S0 1070:1\t|S1 477:1\r\n6\t|S0 1154:1\t|S1 507:1\r\n6\t|S0 321:1\t|S1 485:1\r\n6\t|S0 357:1\t|S1 484:1\r\n6\t|S0 653:1\t\r\n7\t|S0 1160:1\t|S1 245:1\r\n7\t|S0 569:1\t|S1 398:1\r\n7\t|S0 1052:1\t|S1 402:1\r\n7\t|S0 1128:1\t|S1 245:1\r\n7\t|S0 739:1\t|S1 399:1\r\n7\t|S0 357:1\t|S1 1000:1\r\n7\t|S0 447:1\t\r\n7\t|S0 406:1\t\r\n7\t|S0 493:1\t\r\n8\t|S0 1154:1\t|S1 951:1\r\n8\t|S0 276:1\t|S1 949:1\r\n8\t|S0 569:1\t|S1 953:1\r\n8\t|S0 357:1\t|S1 951:1\r\n8\t|S0 549:1\t|S1 950:1\r\n8\t\t|S1 952:1\r\n9\t|S0 1160:1\t|S1 876:1\r\n9\t|S0 337:1\t|S1 752:1\r\n9\t|S0 357:1\t|S1 926:1\r\n9\t|S0 803:1\t|S1 861:1\r\n9\t|S0 435:1\t|S1 379:1\r\n9\t|S0 18:1\t|S1 920:1\r\n10\t|S0 1160:1\t|S1 876:1\r\n10\t|S0 321:1\t|S1 752:1\r\n10\t|S0 357:1\t|S1 926:1\r\n10\t|S0 939:1\t|S1 876:1\r\n10\t|S0 1172:1\t|S1 889:1\r\n10\t\t|S1 920:1\r\n11\t|S0 1160:1\t|S1 956:1\r\n11\t|S0 807:1\t|S1 958:1\r\n11\t|S0 357:1\t|S1 55:1\r\n11\t|S0 894:1\t|S1 956:1\r\n11\t|S0 1128:1\t|S1 787:1\r\n11\t|S0 406:1\t|S1 7:1\r\n11\t|S0 493:1\t\r\n12\t|S0 1160:1\t|S1 876:1\r\n12\t|S0 321:1\t|S1 304:1\r\n12\t|S0 357:1\t|S1 303:1\r\n12\t|S0 803:1\t|S1 876:1\r\n12\t|S0 435:1\t|S1 880:1\r\n12\t|S0 127:1\t|S1 920:1\r\n12\t|S0 204:1\t\r\n13\t|S0 1154:1\t|S1 876:1\r\n13\t|S0 1037:1\t|S1 752:1\r\n13\t|S0 337:1\t|S1 926:1\r\n13\t|S0 357:1\t|S1 113:1\r\n13\t|S0 803:1\t|S1 114:1\r\n13\t|S0 435:1\t|S1 920:1\r\n14\t|S0 1154:1\t|S1 507:1\r\n14\t|S0 80:1\t|S1 485:1\r\n14\t|S0 61:1\t|S1 484:1\r\n14\t|S0 1052:1\t\r\n14\t|S0 565:1\t\r\n14\t|S0 357:1\t\r\n14\t|S0 648:1\t\r\n15\t|S0 1157:1\t|S1 501:1\r\n15\t|S0 321:1\t|S1 452:1\r\n15\t|S0 1052:1\t|S1 533:1\r\n15\t|S0 357:1\t\r\n15\t|S0 630:1\t\r\n16\t|S0 1160:1\t|S1 356:1\r\n16\t|S0 804:1\t|S1 357:1\r\n16\t|S0 357:1\t|S1 733:1\r\n16\t|S0 549:1\t|S1 356:1\r\n16\t|S0 794:1\t|S1 687:1\r\n16\t|S0 680:1\t|S1 7:1\r\n17\t|S0 1160:1\t|S1 421:1\r\n17\t|S0 1011:1\t|S1 985:1\r\n17\t|S0 357:1\t|S1 995:1\r\n17\t|S0 90:1\t\r\n17\t|S0 827:1\t\r\n18\t|S0 1160:1\t|S1 103:1\r\n18\t|S0 569:1\t|S1 732:1\r\n18\t|S0 357:1\t|S1 165:1\r\n18\t|S0 538:1\t|S1 467:1\r\n18\t|S0 708:1\t|S1 103:1\r\n18\t\t|S1 732:1\r\n18\t\t|S1 465:1\r\n18\t\t|S1 678:1\r\n19\t|S0 1157:1\t|S1 652:1\r\n19\t|S0 569:1\t|S1 652:1\r\n19\t|S0 1052:1\t|S1 436:1\r\n19\t|S0 357:1\t|S1 524:1\r\n19\t|S0 636:1\t|S1 532:1\r\n19\t\t|S1 182:1\r\n20\t|S0 1157:1\t|S1 524:1\r\n20\t|S0 569:1\t|S1 524:1\r\n20\t|S0 357:1\t|S1 208:1\r\n20\t|S0 636:1\t\r\n20\t|S0 746:1\t\r\n20\t|S0 30:1\t\r\n20\t|S0 661:1\t\r\n21\t|S0 1154:1\t|S1 103:1\r\n21\t|S0 996:1\t|S1 732:1\r\n21\t|S0 357:1\t|S1 165:1\r\n21\t|S0 1140:1\t|S1 992:1\r\n21\t|S0 159:1\t|S1 103:1\r\n21\t\t|S1 732:1\r\n21\t\t|S1 991:1\r\n21\t\t|S1 524:1\r\n22\t|S0 1160:1\t|S1 103:1\r\n22\t|S0 321:1\t|S1 825:1\r\n22\t|S0 357:1\t|S1 87:1\r\n22\t|S0 939:1\t|S1 823:1\r\n22\t|S0 1172:1\t|S1 103:1\r\n22\t\t|S1 825:1\r\n22\t\t|S1 88:1\r\n22\t\t|S1 920:1\r\n23\t|S0 1157:1\t|S1 524:1\r\n23\t|S0 569:1\t|S1 524:1\r\n23\t|S0 357:1\t|S1 208:1\r\n23\t|S0 428:1\t\r\n23\t|S0 746:1\t\r\n23\t| ...
#  'valid.pair.tok.ctf.csv': b'0\t|S0 1202:1\t|S1 1017:1\r\n0\t|S0 1157:1\t|S1 685:1\r\n0\t|S0 357:1\t|S1 691:1\r\n0\t|S0 484:1\t|S1 711:1\r\n0\t|S0 1113:1\t|S1 1018:1\r\n0\t|S0 1203:1\t\r\n1\t|S0 1202:1\t|S1 1017:1\r\n1\t|S0 1154:1\t|S1 524:1\r\n1\t|S0 1102:1\t|S1 224:1\r\n1\t|S0 739:1\t|S1 385:1\r\n1\t|S0 475:1\t|S1 1018:1\r\n1\t|S0 357:1\t\r\n1\t|S0 505:1\t\r\n1\t|S0 1203:1\t\r\n2\t|S0 1202:1\t|S1 1017:1\r\n2\t|S0 1160:1\t|S1 507:1\r\n2\t|S0 563:1\t|S1 483:1\r\n2\t|S0 357:1\t|S1 485:1\r\n2\t|S0 243:1\t|S1 1018:1\r\n2\t|S0 1203:1\t\r\n3\t|S0 1202:1\t|S1 1017:1\r\n3\t|S0 1160:1\t|S1 356:1\r\n3\t|S0 804:1\t|S1 357:1\r\n3\t|S0 357:1\t|S1 733:1\r\n3\t|S0 549:1\t|S1 356:1\r\n3\t|S0 4:1\t|S1 687:1\r\n3\t|S0 296:1\t|S1 7:1\r\n3\t|S0 1203:1\t|S1 1018:1\r\n4\t|S0 1202:1\t|S1 1017:1\r\n4\t|S0 1160:1\t|S1 790:1\r\n4\t|S0 337:1\t|S1 790:1\r\n4\t|S0 1052:1\t|S1 272:1\r\n4\t|S0 357:1\t|S1 1018:1\r\n4\t|S0 1180:1\t\r\n4\t|S0 1203:1\t\r\n5\t|S0 1202:1\t|S1 1017:1\r\n5\t|S0 1158:1\t|S1 951:1\r\n5\t|S0 56:1\t|S1 952:1\r\n5\t|S0 569:1\t|S1 449:1\r\n5\t|S0 136:1\t|S1 951:1\r\n5\t|S0 1070:1\t|S1 950:1\r\n5\t|S0 430:1\t|S1 949:1\r\n5\t|S0 559:1\t|S1 1018:1\r\n5\t|S0 357:1\t\r\n5\t|S0 1203:1\t\r\n6\t|S0 1202:1\t|S1 1017:1\r\n6\t|S0 1157:1\t|S1 685:1\r\n6\t|S0 337:1\t|S1 691:1\r\n6\t|S0 357:1\t|S1 716:1\r\n6\t|S0 630:1\t|S1 685:1\r\n6\t|S0 731:1\t|S1 709:1\r\n6\t|S0 1203:1\t|S1 524:1\r\n6\t\t|S1 1018:1\r\n7\t|S0 1202:1\t|S1 1017:1\r\n7\t|S0 1154:1\t|S1 956:1\r\n7\t|S0 934:1\t|S1 957:1\r\n7\t|S0 337:1\t|S1 896:1\r\n7\t|S0 357:1\t|S1 956:1\r\n7\t|S0 803:1\t|S1 787:1\r\n7\t|S0 746:1\t|S1 834:1\r\n7\t|S0 1203:1\t|S1 1018:1\r\n8\t|S0 1202:1\t|S1 1017:1\r\n8\t|S0 1157:1\t|S1 103:1\r\n8\t|S0 80:1\t|S1 0:1\r\n8\t|S0 1052:1\t|S1 824:1\r\n8\t|S0 357:1\t|S1 18:1\r\n8\t|S0 746:1\t|S1 906:1\r\n8\t|S0 30:1\t|S1 1018:1\r\n8\t|S0 1179:1\t\r\n8\t|S0 661:1\t\r\n8\t|S0 1203:1\t\r\n9\t|S0 1202:1\t|S1 1017:1\r\n9\t|S0 1154:1\t|S1 685:1\r\n9\t|S0 275:1\t|S1 691:1\r\n9\t|S0 1140:1\t|S1 600:1\r\n9\t|S0 357:1\t|S1 1018:1\r\n9\t|S0 159:1\t\r\n9\t|S0 549:1\t\r\n9\t|S0 1203:1\t\r\n10\t|S0 1202:1\t|S1 1017:1\r\n10\t|S0 1154:1\t|S1 951:1\r\n10\t|S0 80:1\t|S1 952:1\r\n10\t|S0 961:1\t|S1 942:1\r\n10\t|S0 407:1\t|S1 1018:1\r\n10\t|S0 1078:1\t\r\n10\t|S0 96:1\t\r\n10\t|S0 549:1\t\r\n10\t|S0 357:1\t\r\n10\t|S0 1203:1\t\r\n11\t|S0 1202:1\t|S1 1017:1\r\n11\t|S0 1157:1\t|S1 415:1\r\n11\t|S0 337:1\t|S1 808:1\r\n11\t|S0 1052:1\t|S1 582:1\r\n11\t|S0 357:1\t|S1 1018:1\r\n11\t|S0 993:1\t\r\n11\t|S0 1203:1\t\r\n12\t|S0 1202:1\t|S1 1017:1\r\n12\t|S0 1160:1\t|S1 685:1\r\n12\t|S0 321:1\t|S1 691:1\r\n12\t|S0 357:1\t|S1 892:1\r\n12\t|S0 664:1\t|S1 685:1\r\n12\t|S0 1203:1\t|S1 537:1\r\n12\t\t|S1 891:1\r\n12\t\t|S1 1018:1\r\n13\t|S0 1202:1\t|S1 1017:1\r\n13\t|S0 1154:1\t|S1 524:1\r\n13\t|S0 868:1\t|S1 900:1\r\n13\t|S0 321:1\t|S1 794:1\r\n13\t|S0 1052:1\t|S1 524:1\r\n13\t|S0 357:1\t|S1 793:1\r\n13\t|S0 1098:1\t|S1 790:1\r\n13\t|S0 432:1\t|S1 1018:1\r\n13\t|S0 1203:1\t\r\n14\t|S0 1202:1\t|S1 1017:1\r\n14\t|S0 1154:1\t|S1 685:1\r\n14\t|S0 275:1\t|S1 691:1\r\n14\t|S0 321:1\t|S1 600:1\r\n14\t|S0 357:1\t|S1 1018:1\r\n14\t|S0 187:1\t\r\n14\t|S0 447:1\t\r\n14\t|S0 1203:1\t\r\n15\t|S0 1202:1\t|S1 1017:1\r\n15\t|S0 1154:1\t|S1 876:1\r\n15\t|S0 1037:1\t|S1 304:1\r\n15\t|S0 321:1\t|S1 303:1\r\n15\t|S0 357:1\t|S1 876:1\r\n15\t|S0 803:1\t|S1 880:1\r\n15\t|S0 435:1\t|S1 920:1\r\n15\t|S0 422:1\t|S1 1018:1\r\n15\t|S0 1203:1\t\r\n16\t|S0 1202:1\t|S1 1017:1\r\n16\t|S0 1154:1\t|S1 524:1\r\n16\t|S0 288:1\t|S1 900:1\r\n16\t|S0 337:1\t|S1 406:1\r\n16\t|S0 357:1\t|S1 545:1\r\n16\t|S0 190:1\t|S1 256:1\r\n16\t|S0 1117:1\t|S1 235:1\r\n16\t|S0 1203:1\t|S1 1018:1\r\n17\t|S0 1202:1\t|S1 1017:1\r\n17\t|S0 1154:1\t|S1 524:1\r\n17\t|S0 1102:1\t|S1 224:1\r\n17\t|S0 739:1\t|S1 385:1\r\n17\t|S0 475:1\t|S1 1018:1\r\n17\t|S0 337:1\t\r\n17\t|S0 1052:1\t\r\n17\t|S0 437:1\t\r\n17\t|S0 357:1\t\r\n17\t|S0 505:1\t\r\n17\t|S0 1203:1\t\r\n18\t|S0 1202:1\t|S1 1017:1\r\n18\t|S0 1157:1\t|S1 421:1\r\n18\t|S0 337:1\t|S1 730:1\r\n18\t|S0 357:1\t|S1 42 ...
#  'vocab_A.wl.csv': b'aareas \r\nabbreviated_topic \r\nacademic \r\naccommodation \r\naccused_of \r\nactivism \r\nactivist \r\nactor \r\nadaptations \r\nadapted_work \r\naddress \r\nadherents \r\nadjectival_form \r\nadjoin_s \r\nadjoining_relationship \r\nadjoins \r\nadjusted_money_value \r\nadjustment_currency \r\nadministrative_area \r\nadministrative_area_type \r\nadministrative_children \r\nadministrative_division \r\nadministrative_division_capital_relationship \r\nadministrative_divisions \r\nadministrative_parent \r\nadopted_character \r\nadoptive_parents \r\nadvertising_characters \r\nadvertisingcharacters \r\nadvisors \r\naffected_area \r\naffected_areas \r\naffected_locations \r\nagencies \r\nagroschim \r\naircraft_fleet_composition \r\naircraft_manufacturer \r\naircraft_model \r\naircraft_models_made \r\naircraft_owner \r\naircraft_ownership_count \r\nairline \r\nairline_airport_presence \r\nairport \r\nairports_served \r\nalbum \r\nalexander \r\namerican_football \r\nameroamigo \r\nancient_wonder \r\nancientegypt \r\nanimal_breed \r\nanthem \r\nappearance_type \r\nappeared_in_tv_episodes \r\nappeared_in_tv_program \r\nappears_in_book \r\nappears_in_ranked_lists \r\nappears_in_these_fictional_universes \r\nappointed_by \r\nappointed_official \r\nappointed_role \r\nappointee \r\nappointees \r\nappointment \r\nappointments \r\narchitect \r\narchitectural_structure_owner \r\narchitecture \r\narea_of_activism \r\narena_stadium \r\nargumentmaps \r\nart_forms \r\nart_subject \r\narthist \r\nartist \r\nartwork_on_the_subject \r\nassassin \r\nassassinated_person \r\nassassination \r\nasset_owner \r\nasset_ownership \r\nassets_owned \r\nassociated_periods_or_movements \r\nassociated_with \r\nastronomical_discovery \r\nastronomy \r\nathlete_extra \r\nathlete_salary \r\nathletes \r\nathletic_performances \r\nauthor \r\naviation \r\naward \r\naward_honor \r\naward_nominated_work \r\naward_nomination \r\naward_nominations \r\naward_nominee \r\naward_winner \r\naward_winning_work \r\nawards \r\nawards_won \r\nbase \r\nbase_equivalent_location \r\nbaseball \r\nbaseball_historical_roster_position \r\nbaseball_player \r\nbaseball_roster_position \r\nbaseball_team \r\nbased_on \r\nbasic_title \r\nbasin_countries \r\nbasketball \r\nbasketball_historical_roster_position \r\nbasketball_player \r\nbasketball_player_stats \r\nbasketball_roster_position \r\nbasketball_team \r\nbatting_statistics \r\nbatting_stats \r\nbeer \r\nbeer_country_region \r\nbeer_style \r\nbeers_from_here \r\nbeliefs \r\nbelongs_to_combatant_group \r\nbiblioness \r\nbibs_location \r\nbibs_topic \r\nbiology \r\nboard_member \r\nboard_members \r\nboats \r\nbody_of_water \r\nbook \r\nbook_character \r\nbook_editions_published \r\nbook_subject \r\nbooks_published \r\nbrand \r\nbrands \r\nbreakup \r\nbreed_of \r\nbroadcast \r\nbroke_up_into \r\nbuilding \r\nbuilding_complex \r\nbuilding_function \r\nbusiness \r\nbusiness_operation \r\ncabinet_member \r\ncabinet_position \r\ncalendar_system \r\ncampuses \r\ncandidate \r\ncanoodled \r\ncapital \r\ncapital_of \r\ncapital_of_administrative_division \r\ncareer_start \r\ncasualties \r\ncategory \r\ncause_of_death \r\ncelebrities \r\ncelebrity \r\ncelebrity_friends \r\ncelestial_object \r\nchampion \r\nchampionships \r\nchannels \r\ncharacter \r\ncharacter_created_by \r\ncharacters \r\nchemistry \r\ncheunger \r\nchild \r\nchildren \r\ncities \r\ncities_served \r\ncities_within \r\ncity \r\ncitytown \r\nclassification \r\ncoach \r\ncoaches \r\ncoaching_history \r\ncollective_term_for_adherents \r\ncolor \r\ncolors \r\ncombatant \r\ncombatants \r\ncommanders \r\ncommon \r\ncompany \r\ncompany_brand_relationship \r\ncompetitions \r\ncompetitions_won \r\ncompetitor \r\ncompetitor_competition_relationship \r\ncompetitors \r\ncomplete_name \r\ncomposer \r\ncompositions \r\ncomputer_videogame \r\ncondition \r\nconsumer_company \r\ncontained_by \r\ncontainedby \r\ncontains \r\ncontains_major_portion_of \r\ncontent \r\ncontestants \r\nc ...
#  'vocab_Q.wl.csv': b'04 \r\n10 \r\n100 \r\n101 \r\n102 \r\n13th \r\n1665 \r\n1800s \r\n1819 \r\n1886 \r\n1922 \r\n1964 \r\n1998 \r\n2 \r\n2003 \r\n2008 \r\n2009 \r\n2010 \r\n2011 \r\n2012 \r\n2013 \r\n24 \r\n2nd \r\n2pm \r\n3 \r\n30 \r\n4 \r\n5 \r\n6 \r\n8am \r\na \r\nabe \r\nabolition \r\nabolitionist \r\nabout \r\nabraham \r\nacademy \r\naccept \r\naccomplice \r\naccomplish \r\naccomplishments \r\nachievements \r\nact \r\nacting \r\nactor \r\nacts \r\nactual \r\nadmit \r\naffiliated \r\nafl \r\nafrica \r\nafter \r\nage \r\nair \r\naircraft \r\nairlines \r\nairport \r\nairports \r\nalan \r\nalbums \r\nalcohol \r\nall \r\nam \r\namd \r\namerica \r\namerican \r\namericans \r\nan \r\nancient \r\nand \r\nangel \r\nannounce \r\nanother \r\nanswers \r\nanthem \r\napart \r\napostle \r\nappear \r\nappliances \r\narabic \r\nare \r\nareas \r\narizona \r\nark \r\narmenia \r\narmy \r\naround \r\nart \r\nartist \r\nartwork \r\nas \r\nassassinated \r\nat \r\nathletes \r\natom \r\nattend \r\nattractions \r\nauburn \r\naugust \r\naustralia \r\nauthor \r\nauthority \r\navengers \r\naverage \r\naward \r\nawards \r\naway \r\naz \r\nba \r\nbabies \r\nbaby \r\nbad \r\nball \r\nbaltimore \r\nband \r\nbank \r\nbaron \r\nbaseball \r\nbased \r\nbasic \r\nbasketball \r\nbattle \r\nbe \r\nbeautiful \r\nbecame \r\nbecome \r\nbeen \r\nbefore \r\nbegin \r\nbeing \r\nbeliefs \r\nbelieve \r\nbella \r\nbelong \r\nben \r\nbeside \r\nbest \r\nbetween \r\nbible \r\nbiggie \r\nbilbo \r\nbill \r\nbio \r\nbiome \r\nbirmingham \r\nblack \r\nblessed \r\nblood \r\nbloody \r\nblowers \r\nbluegrass \r\nboard \r\nbold \r\nbones \r\nbook \r\nbooks \r\nbora \r\nborder \r\nborders \r\nborn \r\nboston \r\nbowl \r\nbowls \r\nboyfriend \r\nbrakes \r\nbranch \r\nbrand \r\nbrazilian \r\nbreak \r\nbreakfast \r\nbreaking \r\nbring \r\nbrother \r\nbrothers \r\nbrown \r\nbuffy \r\nbuilding \r\nbuilt \r\nburied \r\nbusiness \r\nbuy \r\nby \r\ncalabria \r\ncalifornia \r\ncall \r\ncalled \r\ncambodia \r\ncame \r\ncampaign \r\ncan \r\ncanada \r\ncancer \r\ncape \r\ncapital \r\ncapitals \r\ncar \r\ncareer \r\ncars \r\ncase \r\ncatholics \r\ncause \r\ncaused \r\ncc \r\ncells \r\nceltics \r\ncenter \r\ncentered \r\nceremony \r\nchallenges \r\nchampionship \r\nchampionships \r\nchange \r\nchannel \r\nchapel \r\ncharacter \r\ncharacters \r\ncheat \r\ncheated \r\ncheers \r\nchef \r\ncheltenham \r\ncherry \r\nchildren \r\nchina \r\nchris \r\nchristianity \r\nchristmas \r\nchurch \r\ncircumcision \r\ncities \r\ncity \r\ncivil \r\nclinton \r\nclock \r\nclocks \r\nclone \r\nclose \r\nclosest \r\nclub \r\nclubs \r\nco \r\ncoach \r\ncoached \r\ncode \r\ncollege \r\ncolleges \r\ncolombia \r\ncolony \r\ncolor \r\ncolors \r\ncolosseum \r\ncome \r\ncommon \r\ncompany \r\ncompete \r\ncompose \r\ncomposed \r\nconcertos \r\ncondition \r\nconducted \r\nconferences \r\nconsidered \r\nconsist \r\nconstitutional \r\ncontest \r\ncontinent \r\ncontribute \r\ncontribution \r\ncontributions \r\ncontrol \r\ncontrols \r\nconvention \r\ncore \r\ncoronation \r\ncountries \r\ncountry \r\ncounty \r\ncourt \r\ncrazy \r\ncreate \r\ncreated \r\ncreating \r\ncredited \r\ncrisis \r\ncruella \r\nct \r\nculture \r\ncup \r\ncurrency \r\ncurrent \r\ncurrently \r\ncy \r\nd \r\nda \r\ndad \r\ndaddy \r\ndalmatians \r\ndate \r\ndated \r\ndating \r\ndaughter \r\ndawn \r\nday \r\ndays \r\ndc \r\nde \r\ndeath \r\ndecember \r\ndegree \r\ndemand \r\nderived \r\ndescend \r\ndescended \r\ndesigned \r\ndesperate \r\ndevelop \r\ndeville \r\ndevils \r\ndialect \r\ndialects \r\ndiary \r\ndid \r\ndie \r\ndied \r\ndifferent \r\ndirect \r\ndirecting \r\ndirectly \r\ndiscover \r\ndiscovered \r\ndiscoveries \r\ndiscovery \r\ndisease \r\ndistrict \r\ndivision \r\ndna \r\ndo \r\ndoes \r\ndogtown \r\ndoing \r\ndollar \r\ndollars \r\ndominant \r\ndownfall \r\ndowntown \r\ndr \r\ndraft \r\ndrafted \r\ndream \r\ndrive \r\ndriving \r\ndrug \r\ndrugs \r\ndual \r\ndunk \r\nduring \r\ndust \r\ne1 \r\ne3 \r\neach \r\nearthquake \r\neast \r\neat \r\neconomic ...

# %%
#train.pair.tok.ctf.csv
#valid.pair.tok.ctf.csv
#vocab_A.wl.csv
#vocab_A.wl.csv

# %%
import pandas as pd

# %%
train_file  = pd.read_csv('train.pair.tok.ctf.csv')

# %%
validation_file = pd.read_csv('valid.pair.tok.ctf.csv')

# %%
# Define the vocabulary size (QRY-stands for question and ANS stands for answer)
QRY_SIZE = 1204
ANS_SIZE = 1019

# %%
# Create the containers for input feature (x) and the label (y)
qry = C.sequence.input_variable(QRY_SIZE)
ans = C.sequence.input_variable(ANS_SIZE)

# %%
# Create the containers for input feature (x) and the label (y)
axis_qry = C.Axis.new_unique_dynamic_axis('axis_qry')
qry = C.sequence.input_variable(QRY_SIZE, sequence_axis=axis_qry)

axis_ans = C.Axis.new_unique_dynamic_axis('axis_ans')
ans = C.sequence.input_variable(ANS_SIZE, sequence_axis=axis_ans)

# %%
EMB_DIM   = 25 # Embedding dimension
HIDDEN_DIM = 50 # LSTM dimension
DSSM_DIM = 25 # Dense layer dimension  
NEGATIVE_SAMPLES = 5
DROPOUT_RATIO = 0.2

# %%
def create_model(qry, ans):
    with C.layers.default_options(initial_state=0.1):
        qry_vector = C.layers.Sequential([
            C.layers.Embedding(EMB_DIM, name='embed'),
            C.layers.Recurrence(C.layers.LSTM(HIDDEN_DIM), go_backwards=False),
            C.sequence.last,
            C.layers.Dense(DSSM_DIM, activation=C.relu, name='q_proj'),
            C.layers.Dropout(DROPOUT_RATIO, name='dropout qdo1'),
            C.layers.Dense(DSSM_DIM, activation=C.tanh, name='q_enc')
        ])
        
        ans_vector = C.layers.Sequential([
            C.layers.Embedding(EMB_DIM, name='embed'),
            C.layers.Recurrence(C.layers.LSTM(HIDDEN_DIM), go_backwards=False),
            C.sequence.last,
            C.layers.Dense(DSSM_DIM, activation=C.relu, name='a_proj'),
            C.layers.Dropout(DROPOUT_RATIO, name='dropout ado1'),
            C.layers.Dense(DSSM_DIM, activation=C.tanh, name='a_enc')
        ])

    return {
        'query_vector': qry_vector(qry),
        'answer_vector': ans_vector(ans)
    }

# Create the model and store reference in `network` dictionary
network = create_model(qry, ans)

network['query'], network['axis_qry'] = qry, axis_qry
network['answer'], network['axis_ans'] = ans, axis_ans

# %%
def create_loss(vector_a, vector_b):
    qry_ans_similarity = C.cosine_distance_with_negative_samples(vector_a, \
                                                                 vector_b, \
                                                                 shift=1, \
                                                                 num_negative_samples=5)
    return 1 - qry_ans_similarity

# %%
# Model parameters
MAX_EPOCHS = 5
EPOCH_SIZE = 10000
MINIBATCH_SIZE = 50

# %%
# Create trainer
def create_trainer(reader, network):
    
    # Setup the progress updater
    progress_writer = C.logging.ProgressPrinter(tag='Training', num_epochs=MAX_EPOCHS)

    # Set learning parameters
    lr_per_sample     = [0.0015625]*20 + \
                        [0.00046875]*20 + \
                        [0.00015625]*20 + \
                        [0.000046875]*10 + \
                        [0.000015625]
    lr_schedule       = C.learning_parameter_schedule_per_sample(lr_per_sample, \
                                                 epoch_size=EPOCH_SIZE)
    mms               = [0]*20 + [0.9200444146293233]*20 + [0.9591894571091382]
    mm_schedule       = C.learners.momentum_schedule(mms, \
                                                     epoch_size=EPOCH_SIZE, \
                                                     minibatch_size=MINIBATCH_SIZE)
    l2_reg_weight     = 0.0002

    model = C.combine(network['query_vector'], network['answer_vector'])

    #Notify the network that the two dynamic axes are indeed same
    query_reconciled = C.reconcile_dynamic_axes(network['query_vector'], network['answer_vector'])
  
    network['loss'] = create_loss(query_reconciled, network['answer_vector'])
    network['error'] = None

    print('Using momentum sgd with no l2')
    dssm_learner = C.learners.momentum_sgd(model.parameters, lr_schedule, mm_schedule)

    network['learner'] = dssm_learner
 
    print('Using local learner')
    # Create trainer
    return C.Trainer(model, (network['loss'], network['error']), network['learner'], progress_writer)

# %%
# Instantiate the trainer
trainer = create_trainer(train_file, network)
# Out:
# Using momentum sgd with no l2
# Using local learner

# %%
# Train 
def do_train(network, trainer, train_source):
    # define mapping from intput streams to network inputs
    input_map = {
        network['query']: train_source.query,
        network['answer']: train_source.answer
        } 

    t = 0
    for epoch in range(MAX_EPOCHS):         # loop over epochs
        epoch_end = (epoch+1) * EPOCH_SIZE
        while t < epoch_end:                # loop over minibatches on the epoch
            data = train_source.next_minibatch(MINIBATCH_SIZE, input_map= input_map)  # fetch minibatch
            trainer.train_minibatch(data)               # update model with it
            t += MINIBATCH_SIZE

        trainer.summarize_training_progress()

# %%
do_train(network, trainer, train_file)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-fc4989b45062> in <module>()
# ----> 1 do_train(network, trainer, train_file)
#
# <ipython-input-27-5106a91d010d> in do_train(network, trainer, train_source)
#       3     input_map = {
#       4         network['query']: train_source.query,
# ----> 5         network['answer']: train_source.answer
#       6         }
#       7
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'answer'
